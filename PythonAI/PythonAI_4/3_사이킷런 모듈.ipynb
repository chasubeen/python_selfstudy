# %% [markdown]
# # **1. Scikit-learn 모듈**

# %% [markdown]
# * https://scikit-learn.org
# * 대표적인 파이썬 머신러닝 프레임워크
# * 다양한 머신러닝 알고리즘을 제공
# * 다양한 샘플 데이터를 제공
# * 머신러닝 결과를 검증하는 기능을 제공
# * BSD 라이선스이기 때문에 무료로 사용 및 배포가 가능
# * 알고리즘 치트 시트(https://scikit-learn.org/stable/tutorial/machine_learning_map)

# %% [markdown]
# ### **1-1. 목표**

# %% [markdown]
# * 입력(x,y)과 결과(x,y)의 모든 패턴을 학습
# * 학습 이후 다시 입력(x,y)의 모든 패턴을 주고, 제대로 된 결과를 내는지 평가

# %% [markdown]
# ### **1-2. LinearSVC**

# %% [markdown]
# * 클래스를 구분으로 하는 분류 문제에서 각 클래스를 잘 구분하는 방식을 사용하는 알고리즘
# * 지도학습 알고리즘을 사용하는 학습 전용 데이터와 결과 전용 데이터를 함께 가지고 있어야 사용이 가능함

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score # 모델 평가

learn_data  =[[0,0],[1,0],[0,1],[1,1]]
learn_label = [0,0,0,1]

# %%
clf = LinearSVC()

clf.fit(learn_data,learn_label) # 학습 데이터, 결과 데이터(순서대로)
# Out:
# LinearSVC()

# %%
# 테스트 데이터로 예측
test_data = [[0,0],[1,0],[0,1],[1,1]]
test_label = clf.predict(test_data)

# %%
# 예측 결과를 평가
print(test_data,"의 예측 결과 : ",test_label)
print('정답률 : ',accuracy_score([0,0,0,1],test_label))
# Out:
# [[0, 0], [1, 0], [0, 1], [1, 1]] 의 예측 결과 :  [0 0 0 1]
# 정답률 :  1.0
